# %%
import streamlit as st
import pandas as pd
import data_processing as dp
import prompt_chat_config as pcc
from dotenv import load_dotenv
import os

# %%
load_dotenv()
api_key = os.environ.get("OPENAI_API_KEY")

# %%
chat = pcc.prepare_LLM()
template_string = pcc.prepare_template_string()
response_schemas, output_parser, format_instructions = pcc.prepare_chat_schemas()

# %%
df = pd.read_csv("demo_data.csv")

# %%
processed_df = dp.process_species_data(df, chat=chat, output_parser=output_parser, template_string=template_string, format_instructions=format_instructions)
# Out:
# Searching wikipedia for Acacia binervia
# Plant info found!
# Searching wikipedia for Acacia brachybotrya
# Plant info found!
# Searching wikipedia for Acacia buxifolia
# Plant info found!
# Searching wikipedia for Acacia dealbata
# Plant info found!
# Searching wikipedia for Acacia dealbata dealbata
# Plant info found!
# Searching wikipedia for Adenanthera pavonina
# Plant info found!
# Searching wikipedia for Albizia lebbeck
# Plant info found!
# Searching wikipedia for Albizia lebbeck
# Plant info found!
# Searching wikipedia for Andira anthelmia
# Plant info found!
# Searching wikipedia for Andira fraxinifolia
# Plant info found!
# Searching wikipedia for Cedrela odorata
# Plant info found!
# Searching wikipedia for Cedrella odorata
# Plant info found!
# Processing 1 out of 12 :
#  Acacia binervia in Australia
# Native range: central New South Wales from the Hunter Region south, and to Bungonia in the southwest, and continuing south into Victoria
# ...
